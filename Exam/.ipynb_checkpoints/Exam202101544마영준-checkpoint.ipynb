# %%
202101544 마영준

# %%
# 1번 문제부터 4(4)번 문제까지는 종이에 풀었습니다.

# %% [markdown]
# ![1.jpg](attachment:1.jpg)

# %% [markdown]
# ![2.jpg](attachment:2.jpg)

# %%
# 4
# (5)
x = y = z = 2
# df/dx
dfdx = z-6*x*(y**3)*(z**4)
# df/dy
dfdy = -9*(x**2)*(y**2)*(z**4)
# df/dz
dfdz = x-12*(x**2)*(y**3)*(z**3)

print("df/dx : ", dfdx)
print("df/dy : ", dfdy)
print("df/dz : ", dfdz)
# Out:
# df/dx :  -1534
# df/dy :  -2304
# df/dz :  -3070

# %%
202101544 마영준
